# %%
# https://julien.danjou.info/blog/2013/guide-python-static-class-abstract-methods

# %%
import math

# %%
class Pizza(object):
    def __init__(self, size):
        self.size = size
    def get_size(self):
        return self.size

# %%
Pizza.get_size
# Out:
# <function __main__.Pizza.get_size>

# %%
Pizza.get_size() # unbound method
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-2f3b520b6171> in <module>()
# ----> 1 Pizza.get_size() # unbound method
#
# TypeError: get_size() missing 1 required positional argument: 'self'

# %%
Pizza.get_size(Pizza(42)) 
# 인스턴스를 첫 번째 인수로 사용하여 메서드를 호출.
# 하지만 메소드를 호출 할 때마다 클래스를 참조해야함.
# Out:
# 42

# %%
Pizza(42).get_size # bound method(첫 번째 argument가 instance 자체가 되는 method)임에 주목.
# Out:
# <bound method Pizza.get_size of <__main__.Pizza object at 0x000002070CA97470>>

# %%
Pizza(42).get_size() # self로 bound되어있기 때문에 self argument가 자동으로 Pizza instance에 설정되어있다.
# Out:
# 42

# %%
m = Pizza(42).get_size

# %%
m
# Out:
# <bound method Pizza.get_size of <__main__.Pizza object at 0x000002070CBE90B8>>

# %%
m()
# Out:
# 42

# %%
m = Pizza(42).get_size # 이 bound method의 object를 아는 방법: __self__

# %%
m.__self__

# %%
m == m.__self__.get_size
# Out:
# True

# %% [markdown]
# # Static methods

# %%
class Pizza(object):
    @staticmethod # Class 내에 속해있지만 object를 이용하지 않음.
    def mix_ingredients(x, y):
        return x + y
 
    def cook(self):
        return self.mix_ingredients(self.cheese, self.vegetables)

# %%
Pizza().cook is Pizza().cook
# Out:
# False

# %%
Pizza().mix_ingredients is Pizza.mix_ingredients
# Out:
# True

# %%
Pizza().mix_ingredients is Pizza().mix_ingredients
# Out:
# True

# %% [markdown]
# # Class methods

# %%
class Pizza(object):
    radius = 42
    @classmethod # 이 메서드에 어떻게 액세스하든 관계없이 항상 bound되며(?), Class 자체를 인자로 받는다.
    def get_radius(cls):
        return cls.radius

# %%
Pizza.get_radius
# Out:
# <bound method Pizza.get_radius of <class '__main__.Pizza'>>

# %%
Pizza().get_radius
# Out:
# <bound method Pizza.get_radius of <class '__main__.Pizza'>>

# %%
Pizza.get_radius is Pizza().get_radius
# Out:
# False

# %%
Pizza.get_radius()
# Out:
# 42

# %%
class Pizza(object):
    def __init__(self, ingredients):
        self.ingredients = ingredients
        
    @classmethod
    def from_fridge(cls, fridge):
        return cls(fridge.get_cheese() + fridge.get_vegetables())

# %%
class Pizza(object):
    def __init__(self, radius, height):
        self.radius = radius
        self.height = height
 
    @staticmethod
    def compute_area(radius):
         return math.pi * (radius ** 2)
 
    @classmethod
    def compute_volume(cls, height, radius):
         return height * cls.compute_area(radius)
 
    def get_volume(self):
        return self.compute_volume(self.height, self.radius)

# %%
p = Pizza(10, 20)

# %%
p.compute_area()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-665cae8b6555> in <module>()
# ----> 1 p.compute_area()
#
# TypeError: compute_area() missing 1 required positional argument: 'radius'

# %%
p.compute_area(1)
# Out:
# 3.141592653589793

# %%
p.compute_volume(2, 1)
# Out:
# 6.283185307179586
